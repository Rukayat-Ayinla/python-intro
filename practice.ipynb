# %%
print ('Hello world!')
print ('I am learning python!')
print ('programming is fun.')
# Out:
# Hello world!
# I am learning python!
# programming is fun.

# %%
print ('Hello world')
# Out:
# Hello world

# %%
student_name = 'Rukayat'

course_name = 'python Programming'

print('welcome,' + student_name)
print('You are enrolled in:', course_name)
print("I'm excited to learn this course!")

my_name = 'your name'
print ('my name is:', my_name)
print (' goal 1: Build Something cool')
print (' goal 2: To be fast when typing')
print (' goal 3: solve problem')
# Out:
# welcome,Rukayat
# You are enrolled in: python Programming
# I'm excited to learn this course!
# my name is: your name
#  goal 1: Build Something cool
#  goal 2: To be fast when typing
#  goal 3: solve problem

# %%
print("=" * 40)
print("   welcome to my first python script")
print("=" * 40)


name = input("Please enter your name: ")


age = input("Please enter your age: ")


print("\nHello,", name + "!")
print("You are", age, "years old.")
print("Welcome to Python Programming!")
# Out:
# ...
#    welcome to my first python script
# ...
#
# Hello, !
# You are 22 years old.
# Welcome to Python Programming!

# %%
NAME = input("please enter your NAME,")
LEVEL = input("please enter your LEVEL, ")
DEPARTMENT = input("please enter your DEPARTMENT. ")
HOBBY = input("please enter your HOBBY.")

print("\nWELCOME" , NAME +   "YOU HAVE BEEN ENROLLED TO" , LEVEL +   "IN", DEPARTMENT + "." + "WE HAVE NOTED YOU ARE GOOD AT" , HOBBY)
# Out:
# WELCOME RukayatYOU HAVE BEEN ENROLLED TO 300IN Computer.WE HAVE NOTED YOU ARE GOOD AT dancing

# %%
Acceptable_age = 17

Student_age = int(input("please enter your age:"))

if Student_age > Acceptable_age:
    print("welcome")
else:
    print("not eligible.")
# Out:
# welcome

# %%
scores = [85,92,78,95,88]
print(sum(scores))
average = sum(scores) / len (scores)
print ('average score:', average)

message = 'python is amazing'
print('Formatted:', message.title())

file_size_mb = 150
if file_size_mb > 100:
    print('file is large - consider compressing it.')
else:
    print('File size is acceptable.')
# Out:
# 438
# average score: 87.6
# Formatted: Python Is Amazing
# file is large - consider compressing it.

# %%
Score = 85

if Score >= 50:
    print("Result: pass")
    print("Weldone Keep it up!")
else:
    print("Assesstment Complete")
# Out:
# Result: pass
# Weldone Keep it up!

# %%
age = 20

if age >= 18:
    print("you are an adult")
    print("you can vote in an elections")

    print("Age check Complete")
# Out:
# you are an adult
# you can vote in an elections
# Age check Complete

# %%
product_price = 250.00        # <-- amount of product 
discount_rate = 0.15          # The Rate discounted from the amount
discount_amount = product_price * discount_rate  # To get discount rate product price shold e multiplied by discount_rate
final_price = product_price - discount_amount # to get the final price the product price should be deducted from the discount amount

print("Original price:", product_price)
print("Discount:", discount_amount)
print("Final price:", final_price)
# Out:
# Original price: 250.0
# Discount: 37.5
# Final price: 212.5

# %%
print("python", "is fun")
print("python is fun")

print("2024", "01", "15" , sep="-")

print("loading", end= "...")
print("complete!")

print()

for i in range (5):
    print("*" , end= "")
print() 

questions = [
    "what is a list?", "what is an object?", "what is a tuple?", "what is their difernce?"
]
for question in questions:
    print(question)
# Out:
# python is fun
# python is fun
# 2024-01-15
# loading...complete!
#
# *****
# what is a list?
# what is an object?
# what is a tuple?
# what is their difernce?

# %%
item1 = "Notebook"
price1 = 5.50
item2 = "Pen"
price2 = 3.50
item3 = "Bag"
price3 = 4.60

Total = int(5.50 + 3.50 + 4.60)
# print("Thank you for patronising with us")

# %%
N = int(input("input a number: "))

while N > 20 and N < 1:
   N =  int(input("input a number "))
    
for i in range(N, 0, -1):
           print(str(i) * i)

new_num = N * 20
count = 0

for i in range(1, new_num,):
       
   if i  % N == 0:
         continue

   print(i)

   count += 1

   if count == 5:
         break
# Out:
# 151515151515151515151515151515
# 1414141414141414141414141414
# 13131313131313131313131313
# 121212121212121212121212
# 1111111111111111111111
# 10101010101010101010
# 999999999
# 88888888
# 7777777
# 666666
# 55555
# 4444
# 333
# 22
# 1
# 1
# 2
# 3
# 4
# 5

# %%
word = "avocadro@gmail.com"
print(word[0])
print(word[-1])
print(word[:5])
print(word[::-1])
position = word.find("@")
print(word[position + 1:])
print(word[:position])
# Out:
# a
# m
# avoca
# moc.liamg@ordacova
# gmail.com
# avocadro

# %%
text = "Data Science and Machine Learning"

print(text[:4])

l_position = text.find("L")
print(text[l_position - 1:])
print(text[:4])
print(text[::-1])
# Out:
# Data
#  Learning
# Data
# gninraeL enihcaM dna ecneicS ataD

# %%
shoe_price = 50000

if shoe_price < 45000:
        print('buy')
else: 
        print('dont buy')
# Out:
# dont buy

# %%
python_uses = [
    'Web Development',
    'Data Science',
    'Automation',
    'Cybersecurity',
    'Scientific Research.'
]

print('python is used for:')
for use in python_uses:
    print('- ', use)

print('\nTotal domains:', len(python_uses))
# Out:
# python is used for:
# -  Web Development
# -  Data Science
# -  Automation
# -  Cybersecurity
# -  Scientific Research.
#
# Total domains: 5

# %% [markdown]
# # Hello, I'm Rukayat
#
# ## Hello, I'm Rukayat
#
# ### Hello, I'm Rukayat
#
# - List one
# - List two
